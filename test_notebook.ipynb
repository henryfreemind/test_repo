# %% [markdown]
# # Einstiegstest
# ## Basisworkshop Massendatenanalyse
#
# **Bearbeitungszeit:** ca. 20–30 Minuten
# **Zweck:** kurze Einschätzung von Motivation, Vorkenntnissen, technischer Affinität und grundlegender analytischer Eignung.
# **Hinweis:** Programmierkenntnisse werden **nicht** vorausgesetzt. Der Test prüft insbesondere Motivation, Excel-Grundlagen, Zahlenverständnis, strukturiertes Denken und den Umgang mit tabellarischen Daten.
#
# ### Bearbeitungshinweise
# 1. Führen Sie die Zellen der Reihe nach aus.
# 2. Tragen Sie Ihre Antworten in den vorgesehenen Variablen ein.
# 3. Speichern Sie das Notebook am Ende oder exportieren Sie die Ergebnisdatei.
# 4. Freitextantworten sollen kurz, aber nachvollziehbar sein.
#
# Die Konzeption dieses Tests orientiert sich am Seminarplan: Das Seminar setzt grundlegende Excel-Kenntnisse, mathematisch-technische Affinität, Interesse an Daten und ein grundlegendes algorithmisches Verständnis voraus. Der vorgesehene Selbsttest soll aus einem Motivations- und Selbsteinschätzungsteil sowie einem kurzen praxisorientierten Testteil bestehen.

# %%
# Bitte ausführen
import pandas as pd
import json
from datetime import datetime
from pathlib import Path

print("Umgebung erfolgreich geladen.")
# Out:
# Umgebung erfolgreich geladen.

# %%
# Beispieldatensatz für die Aufgaben
daten = pd.DataFrame([
    {"rechnung_id": 1001, "kreditor": "Alpha GmbH",   "datum": "2026-01-05", "betrag_eur": 950,  "kostenart": "Büro",        "referat": "11"},
    {"rechnung_id": 1002, "kreditor": "Beta AG",      "datum": "2026-01-05", "betrag_eur": 1200, "kostenart": "IT",          "referat": "12"},
    {"rechnung_id": 1003, "kreditor": "Gamma KG",     "datum": "2026-01-06", "betrag_eur": 1200, "kostenart": "IT",          "referat": "12"},
    {"rechnung_id": 1004, "kreditor": "Alpha GmbH",   "datum": "2026-01-07", "betrag_eur": 300,  "kostenart": "Büro",        "referat": "14"},
    {"rechnung_id": 1005, "kreditor": "Delta GmbH",   "datum": "2026-01-07", "betrag_eur": 4800, "kostenart": "Fortbildung", "referat": "12"},
    {"rechnung_id": 1006, "kreditor": "Beta AG",      "datum": "2026-01-08", "betrag_eur": 1200, "kostenart": "IT",          "referat": "12"},
    {"rechnung_id": 1006, "kreditor": "Beta AG",      "datum": "2026-01-08", "betrag_eur": 1200, "kostenart": "IT",          "referat": "12"},
    {"rechnung_id": 1007, "kreditor": "Epsilon e.V.", "datum": "2026-01-09", "betrag_eur": 75,   "kostenart": "Bewirtung",   "referat": "11"},
    {"rechnung_id": 1008, "kreditor": "Zeta OHG",     "datum": "2026-01-10", "betrag_eur": 9999, "kostenart": "IT",          "referat": "14"},
    {"rechnung_id": 1009, "kreditor": "Alpha GmbH",   "datum": "2026-01-11", "betrag_eur": 950,  "kostenart": "Büro",        "referat": "11"},
])

daten
# Out:
#    rechnung_id      kreditor       datum  betrag_eur    kostenart referat
# 0         1001    Alpha GmbH  2026-01-05         950         Büro      11
# 1         1002       Beta AG  2026-01-05        1200           IT      12
# 2         1003      Gamma KG  2026-01-06        1200           IT      12
# 3         1004    Alpha GmbH  2026-01-07         300         Büro      14
# 4         1005    Delta GmbH  2026-01-07        4800  Fortbildung      12
# 5         1006       Beta AG  2026-01-08        1200           IT      12
# 6         1006       Beta AG  2026-01-08        1200           IT      12
# 7         1007  Epsilon e.V.  2026-01-09          75    Bewirtung      11
# 8         1008      Zeta OHG  2026-01-10        9999           IT      14
# 9         1009    Alpha GmbH  2026-01-11         950         Büro      11

# %% [markdown]
# Das hier ist neuer Text, den ich in Colab geschrieben habe.
